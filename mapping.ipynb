# %%
# %matplotlib ipympl
from laser_calibration import *

# %%
stereo_params_path = "params/example_stereo_params.pkl" # stereo camera params path from stereocamera calibration
laser_pose_path = "params/example_laser_params.pkl" # path to the laser pose params from laser calibration
images_path = "mapping_input/example/images" # path to mapping images captured with cam_data_collection.py/mapping_collection
points_path = "mapping_input/jul21/npys" # path to save 2D points of scanning spots extrcted during get_mapping_points2d

with open(stereo_params_path, "rb") as f:
    stereo_params = pickle.load(f)
with open(laser_pose_path, "rb") as f:
    laser_params = pickle.load(f)

get_mapping_points2d(images_path, stereo_params, output_folder_path=points_path, manual_approve=True) 
get_mapping_functions(stereo_params, laser_params, input_folder_path = points_path, output_folder_path = "params/")
# Out:
# Mirror x RMS: 9.113597951542644
# Mirror y RMS: 9.275488046500769
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
